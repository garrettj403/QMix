# %% [markdown]
# # Profile qtcurrent
#
# To run this notebook, you'll need `py-heat-magic`:
#
#     pip install py-heat-magic

# %%
# %load_ext heat

import qmix

# %% [markdown]
# # 1 Tone

# %%
# %%heat
#
# import qmix
#
# # Setup ----------------------------------------------------------------------
#
# resp = qmix.respfn.RespFnPolynomial(50, verbose=False)
#
# num_b = (10, 5, 5, 5)
#
# # 1 tone ---------------------------------------------------------------------
#
# cct = qmix.circuit.EmbeddingCircuit(1, 1)
# cct.vph[1] = 0.3
#
# vj = cct.initialize_vj()
# vj[1,1,:] = 0.3
#
# idc = qmix.qtcurrent.qtcurrent(vj, cct, resp, 0.,  num_b=num_b, verbose=False)
# iac = qmix.qtcurrent.qtcurrent(vj, cct, resp, 0.3, num_b=num_b, verbose=False)

# %% [markdown]
# # 2 Tones

# %%
# %%heat
#
# import qmix
#
# # Setup ----------------------------------------------------------------------
#
# resp = qmix.respfn.RespFnPolynomial(50, verbose=False)
#
# num_b = (10, 5, 5, 5)
#
# # 2 tone ---------------------------------------------------------------------
#
# cct = qmix.circuit.EmbeddingCircuit(2, 1)
# cct.vph[1] = 0.30
# cct.vph[2] = 0.33
#
# vj = cct.initialize_vj()
# vj[1,1,:] = 0.3
# vj[2,1,:] = 0.1
#
# idc = qmix.qtcurrent.qtcurrent(vj, cct, resp, 0.,  num_b=num_b, verbose=False)
# iac = qmix.qtcurrent.qtcurrent(vj, cct, resp, 0.3, num_b=num_b, verbose=False)

# %% [markdown]
# # 3 Tones

# %%
# %%heat
#
# import qmix
#
# # Setup ----------------------------------------------------------------------
#
# resp = qmix.respfn.RespFnPolynomial(50, verbose=False)
#
# num_b = (10, 5, 5, 5)
#
# # 3 tone ---------------------------------------------------------------------
#
# cct = qmix.circuit.EmbeddingCircuit(3, 1)
# cct.vph[1] = 0.30
# cct.vph[2] = 0.33
# cct.vph[3] = 0.27
#
# vj = cct.initialize_vj()
# vj[1,1,:] = 0.3
# vj[2,1,:] = 0.1
# vj[3,1,:] = 0.1
#
# idc  = qmix.qtcurrent.qtcurrent(vj, cct, resp, 0.,   num_b=num_b, verbose=False)
# iac1 = qmix.qtcurrent.qtcurrent(vj, cct, resp, 0.3,  num_b=num_b, verbose=False)
# iac1 = qmix.qtcurrent.qtcurrent(vj, cct, resp, 0.03, num_b=num_b, verbose=False)

# %% [markdown]
# # 4 Tones

# %%
# %%heat
#
# import qmix
#
# # Setup ----------------------------------------------------------------------
#
# resp = qmix.respfn.RespFnPolynomial(50, verbose=False)
#
# num_b = (10, 5, 5, 5)
#
# # 4 tone ---------------------------------------------------------------------
#
# cct = qmix.circuit.EmbeddingCircuit(4, 1)
# cct.vph[1] = 0.30
# cct.vph[2] = 0.33
# cct.vph[3] = 0.27
# cct.vph[4] = 0.03
#
# vj = cct.initialize_vj()
# vj[1,1,:] = 0.3
# vj[2,1,:] = 0.1
# vj[3,1,:] = 0.1
# vj[4,1,:] = 0.0
#
# idc  = qmix.qtcurrent.qtcurrent(vj, cct, resp, 0.,   num_b=num_b, verbose=False)
# iac1 = qmix.qtcurrent.qtcurrent(vj, cct, resp, 0.3,  num_b=num_b, verbose=False)
# iac2 = qmix.qtcurrent.qtcurrent(vj, cct, resp, 0.03, num_b=num_b, verbose=False)
